# %% [markdown]
# # 5.2 Attribute join and spatial join
#
#
# <br></br>
# <font size="3">There are two ways to combine datasets in `geopandas` – attribute joins and spatial joins.
# <br></br>
# <br></br>
# In an attribute join, a `GeoSeries` or `GeoDataFrame` is combined with a regular pandas Series or DataFrame based on a <b>common variable</b>. This is analogous to normal merging or joining in pandas.
# <br></br>
# <br></br>
# In a Spatial Join, observations from to GeoSeries or GeoDataFrames are combined based on their spatial relationship to one another.</font>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <br></br>
# <font size="3"> Let's play around with those methods using the US lower 48 states example.</font>

# %%
states = gpd.read_file("/Users/Ziqi/Desktop/ASU-GIS-322-Fall-19/data/US_lower_48/US_lower_48.shp")

# %%
states.plot()

# %% [markdown]
# <br></br>
# <font size="3"> First of all, let's calculate the centroid of each state.</font>

# %%
states.centroid
# Out:
# 0     POINT (-80.61370688838748 38.64256703184511)
# 1     POINT (-82.46641838879964 28.47705841502811)
# 2     POINT (-89.14863897474164 40.12420082537884)
# 3      POINT (-94.19833862559696 46.3492686703704)
# 4     POINT (-76.68717734222649 38.94649395901635)
# 5     POINT (-114.6594149963059 44.38905512994051)
# 6     POINT (-71.57124288466969 43.68023661955591)
# 7      POINT (-79.13089476156279 35.5260354155783)
# 8     POINT (-72.66263036304007 44.07524824200586)
# 9     POINT (-72.73825767425733 41.57516415002651)
# 10      POINT (-75.4524925800085 38.9949748478596)
# 11     POINT (-106.108443877689 34.42130101404501)
# 12    POINT (-119.6638460808195 37.21530841878715)
# 13    POINT (-74.65561246420474 40.11017976951747)
# 14    POINT (-89.73293305799305 44.63994413183933)
# 15     POINT (-120.605256220487 43.94045138846253)
# 16    POINT (-99.81086234871262 41.52714793297905)
# 17     POINT (-77.8389379964412 40.89670050239954)
# ...

# %%
states.centroid.plot()

# %% [markdown]
# <br></br>
# <font size="3">Overlay state centroids with the state polygons.</font>

# %%
fig, ax = plt.subplots(1, 1,figsize=(10,8))
states.plot(ax=ax)
states.centroid.plot(ax=ax,color="red")

# %% [markdown]
# <br></br>
# <font size="3">Then, let's create a buffer to each of the centroid. Before we do that, one important step is to check the projection. If you remember, this one is not projected.</font>

# %%
states.crs
# Out:
# {'init': 'epsg:4269'}

# %%
states_projected = states.to_crs(epsg='3857')

# %% [markdown]
# <br></br>
# <font size="3">Project it to mercator, so the the buffering distance will be in the unit of meters rather than arc-degree. </font>

# %%
buffers = states_projected.centroid.buffer(distance=200000) #This is a 200 kilometer buffer

# %%
fig, ax = plt.subplots(1, 1,figsize=(10,8))
states_projected.plot(ax=ax)
buffers.plot(ax=ax,color="green")
states_projected.centroid.plot(ax=ax,color="red")

# %% [markdown]
# <br></br>
# <font size="3">Then let's calcuate the area and length of each state, and create two new columns in the states GeoDataFrame.</font>

# %%
states_projected['state_area'] = states_projected.area
states_projected['state_length'] = states_projected.length

# %% [markdown]
# <br></br>
# <font size="3">Let's find out which state has the largest area? Have a guess before running the command?</font>

# %%
states_projected.sort_values('state_area', ascending=False)[['NAME','state_area']]
# Out:
#                     NAME    state_area
# 24                 Texas  9.607227e+11
# 39               Montana  8.201831e+11
# 12            California  6.718940e+11
# 35              Michigan  4.997446e+11
# 15                Oregon  4.919326e+11
# 34                Nevada  4.802968e+11
# 29               Wyoming  4.741973e+11
# 3              Minnesota  4.732057e+11
# 11            New Mexico  4.644023e+11
# 25              Colorado  4.473108e+11
# 47               Arizona  4.340643e+11
# 5                  Idaho  4.246751e+11
# 18            Washington  4.032408e+11
# 30          North Dakota  4.003531e+11
# 42          South Dakota  3.919818e+11
# 22                  Utah  3.682859e+11
# 16              Nebraska  3.578636e+11
# 40                Kansas  3.484440e+11
# 14             Wisconsin  3.353652e+11
# 38              Missouri  2.943632e+11
# 27              Oklahoma  2.744188e+11
# 46                  Iowa  2.648092e+11
# 33              New York  2.637690e+11
# ...

# %% [markdown]
# <br></br>
# <font size="3">Let's find out which state has the largest length (circumference)? Have another guess?</font>

# %%
states_projected.sort_values('state_length', ascending=False)[['NAME','state_length']]
# Out:
#                     NAME  state_length
# 24                 Texas  6.845591e+06
# 12            California  5.257989e+06
# 39               Montana  4.615753e+06
# 3              Minnesota  4.510422e+06
# 5                  Idaho  4.197446e+06
# 35              Michigan  3.795814e+06
# 1                Florida  3.734787e+06
# 27              Oklahoma  3.307801e+06
# 15                Oregon  3.282428e+06
# 33              New York  3.212606e+06
# 30          North Dakota  3.125605e+06
# 19             Louisiana  3.078644e+06
# 34                Nevada  3.054836e+06
# 38              Missouri  3.050107e+06
# 14             Wisconsin  3.030128e+06
# 42          South Dakota  2.963038e+06
# 44              Virginia  2.949640e+06
# 18            Washington  2.926237e+06
# 16              Nebraska  2.922198e+06
# 47               Arizona  2.907360e+06
# 11            New Mexico  2.900303e+06
# 2               Illinois  2.861004e+06
# 37           Mississippi  2.855253e+06
# ...
